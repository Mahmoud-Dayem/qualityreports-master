# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
oxides = ['SiO2', 'Al2O3', 'Fe2O3', 'CaO', 'MgO', 'SO3', 'Na2O', 'K2O', 'Na2O', 'Cl']

# %%
df = pd.read_csv('5- ChemicalClinkerMonthly.csv')

# %%
df.columns
# Out:
# Index(['SiO2', 'Al2O3', 'Fe2O3', 'CaO', 'MgO', 'SO3', 'Na2O', 'K2O', 'Na2O.1',
#        'Cl', 'FreeCaO', 'LSF', 'SR', 'AF', 'C3S', 'C2S', 'C3A', 'C4AF',
#        'C4AFplus2C3A', 'Liquid', 'litreweight'],
#       dtype='object')

# %%
df.describe()
# Out:
#             SiO2      Al2O3     Fe2O3        CaO        MgO       SO3   \
# count  31.000000  31.000000  31.00000  31.000000  31.000000  31.000000
# mean   21.433548   4.374839   4.63871  63.177419   4.297419   0.896774
# std     0.061997   0.063764   0.08667   0.082944   0.168463   0.040364
# min    21.290000   4.250000   4.52000  63.010000   4.030000   0.830000
# 25%    21.380000   4.340000   4.57500  63.115000   4.170000   0.870000
# 50%    21.430000   4.390000   4.64000  63.170000   4.280000   0.900000
# 75%    21.475000   4.415000   4.67500  63.220000   4.415000   0.925000
# max    21.580000   4.480000   4.85000  63.390000   4.670000   0.980000
#
#             Na2O        K2O     Na2O.1            Cl  ...        LSF  \
# count  31.000000  31.000000  31.000000  3.100000e+01  ...  31.000000
# mean    0.123226   0.444516   0.415161  2.000000e-02  ...  91.728065
# std     0.024818   0.020791   0.022930  3.526797e-18  ...   0.220037
# ...

# %%
df.columns
# Out:
# Index(['SiO2', 'Al2O3', 'Fe2O3', 'CaO', 'MgO', 'SO3 ', 'Na2O', 'K2O', 'Na2O.1',
#        'Cl', 'FreeCaO', 'LSF', 'SR', 'AF', 'C3S', 'C2S', 'C3A', 'C4AF',
#        'C4AFplus2C3A', 'Liquid', 'litreweight'],
#       dtype='object')

# %%
oxides = ['SiO2', 'Al2O3', 'Fe2O3', 'CaO', 'MgO', 'SO3 ', 'Na2O', 'K2O', 'Na2O.1', 'Cl']

cols = 4  # number of plots per row
rows = math.ceil(len(oxides) / cols)

plt.figure(figsize=(15, 5 * rows))

for i, oxide in enumerate(oxides, 1):
    plt.subplot(rows, cols, i)
    sns.boxplot(y=df[oxide] ,  color='skyblue')
    plt.title(oxide)

plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['SiO2', 'Al2O3', 'Fe2O3', 'CaO', 'MgO', 'SO3', 'Na2O', 'K2O', 'Na2O.1',
#        'Cl', 'FreeCaO', 'LSF', 'SR', 'AF', 'C3S', 'C2S', 'C3A', 'C4AF',
#        'C4AFplus2C3A', 'Liquid', 'litreweight'],
#       dtype='object')

# %%
modules = ['LSF', 'SR', 'AF']

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import math

oxides = ['SiO2', 'Al2O3', 'Fe2O3', 'CaO', 'MgO', 'SO3', 'Na2O', 'K2O', 'Na2O.1', 'Cl']
oxides = [o.strip() for o in oxides]

cols = 3
rows = math.ceil(len(oxides) / cols)

plt.figure(figsize=(15, 5 * rows))

for i, oxide in enumerate(oxides, 1):
    plt.subplot(rows, cols, i)
    
    data = df[oxide].dropna()
    sns.boxplot(y=data, color='skyblue')
    
    # calculate stats
    min_val = data.min()
    max_val = data.max()
    median_val = data.median()
    
    # add text annotations
    plt.text(0, min_val, f'Min: {min_val:.2f}', ha='center', va='top', color='red')
    plt.text(0, max_val, f'Max: {max_val:.2f}', ha='center', va='bottom', color='green')
    plt.text(0, median_val, f'Med: {median_val:.2f}', ha='center', va='center', color='blue')
    
    plt.title(oxide)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import math

 
oxides = [o.strip() for o in modules]

cols = 3
rows = math.ceil(len(oxides) / cols)

plt.figure(figsize=(15, 5 * rows))

for i, oxide in enumerate(oxides, 1):
    plt.subplot(rows, cols, i)
    
    data = df[oxide].dropna()
    sns.boxplot(y=data, color='skyblue')
    
    # calculate stats
    min_val = data.min()
    max_val = data.max()
    median_val = data.median()
    
    # add text annotations
    plt.text(0, min_val, f'Min: {min_val:.2f}', ha='center', va='top', color='red')
    plt.text(0, max_val, f'Max: {max_val:.2f}', ha='center', va='bottom', color='green')
    plt.text(0, median_val, f'Med: {median_val:.2f}', ha='center', va='center', color='blue')
    
    plt.title(oxide)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import math

oxides = ['SiO2', 'Al2O3', 'Fe2O3', 'CaO', 'MgO', 'SO3 ', 'Na2O', 'K2O', 'Na2O.1', 'Cl']
oxides = [o.strip() for o in modules]

cols = 3
rows = math.ceil(len(oxides) / cols)

plt.figure(figsize=(15, 5 * rows))

for i, oxide in enumerate(oxides, 1):
    plt.subplot(rows, cols, i)
    
    data = df[oxide].dropna()
    
    sns.histplot(x=data, color='skyblue', )  # 👈 shows mini boxplot inside
    sns.violinplot(x=data, color='skyblue' )  # 👈 shows mini boxplot inside
 
 
    plt.title(oxide)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import math

oxides = ['SiO2', 'Al2O3', 'Fe2O3', 'CaO', 'MgO', 'SO3 ', 'Na2O', 'K2O', 'Na2O.1', 'Cl']
oxides = [o.strip() for o in modules]

cols = 3
rows = math.ceil(len(oxides) / cols)

plt.figure(figsize=(15, 5 * rows))

for i, oxide in enumerate(oxides, 1):
    plt.subplot(rows, cols, i)
    
    data = df[oxide].dropna()
    
    # 🎻 Violin (background)
    sns.violinplot(y=data, color='lightgray', inner=None)
    
    # 📦 Boxplot (overlay)
    sns.boxplot(
        y=data,
        width=0.2,              # narrow box
        color='white',
        boxprops={'zorder': 2},
        showfliers=False        # optional: hide outliers for cleaner look
    )
    
    plt.title(oxide)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import math

oxides = ['SiO2', 'Al2O3', 'Fe2O3', 'CaO', 'MgO', 'SO3 ', 'Na2O', 'K2O', 'Na2O.1', 'Cl']
oxides = [o.strip() for o in modules]

cols = 3
rows = math.ceil(len(oxides) / cols)

plt.figure(figsize=(15, 5 * rows))

for i, oxide in enumerate(oxides, 1):
    plt.subplot(rows, cols, i)
    
    data = df[oxide].dropna()
    
    # 🎻 Violin (background)
    sns.violinplot(x=data, color='lightgray', inner=None)
    
    # 📊 Histogram (overlay, horizontal to match y-axis)
    sns.histplot(
        x=data,
        bins=20,
        color='blue',
        alpha=0.3,
        kde=True   # adds smooth curve
    )
    
    plt.title(oxide)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import math

oxides = ['SiO2', 'Al2O3', 'Fe2O3', 'CaO', 'MgO', 'SO3 ', 'Na2O', 'K2O', 'Na2O.1', 'Cl']
oxides = [o.strip() for o in modules]

cols = 3
rows = math.ceil(len(oxides) / cols)

plt.figure(figsize=(15, 5 * rows))

for i, oxide in enumerate(oxides, 1):
    plt.subplot(rows, cols, i)
    
    data = df[oxide].dropna()
    
    # 🎻 Violin (background)
 
    # 📊 Histogram (overlay, horizontal to match y-axis)
    sns.histplot(
        x=data,
        bins=20,
        color='blue',
        alpha=0.3,
        kde=True   # adds smooth curve
    )
    
    plt.title(oxide)

plt.tight_layout()
plt.show()

# %% [markdown]
# ✅ Swarmplot only (3 per row)

# %%
import seaborn as sns

palette = sns.color_palette("tab10", len(modules))

plt.figure(figsize=(15, 5 * rows))

for i, (oxide, color) in enumerate(zip(modules, palette), 1):
    plt.subplot(rows, cols, i)
    
    data = df[oxide].dropna()
    
    sns.violinplot(y=data, color='lightgray', inner=None)
    sns.swarmplot(y=data, color=color, size=2)
    
    plt.title(oxide)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 10))
sns.pairplot(df[modules])
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))

sns.heatmap(
    df[modules],
    annot=True,
    fmt=".2f",          # show 2 decimal places
    cmap="coolwarm",    # color style
    linewidths=0.5
)

plt.title("Heatmap of Modules")
plt.show()

# %% [markdown]
# 🔥 Most important type: Correlation heatmap

# %%
corr = df[modules].corr()
sns.heatmap(corr, annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr = df.corr(numeric_only=True)

plt.figure(figsize=(12, 8))

sns.heatmap(
    corr,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    vmin=-1,
    vmax=1
)

plt.title("Clinker Chemistry Correlation Heatmap")
plt.show()

# %% [markdown]
# # Quaryy blasting analysis

# %%
df = pd.read_csv('blasting.csv')

# %%
df.head()
# Out:
#      rows   SiO2  Al2O3  Fe2O3    CaO   MgO   SO3   K2O  Na2O    CL     LSF  \
# 0    A1-2  13.76   1.29   1.14  38.84  7.35  0.61  0.11  0.05  0.02   95.22
# 1    A1-5   4.16   1.05   1.24  50.68  1.12  0.22  0.16  0.04  0.01  370.12
# 2  A1-6.5  11.64   1.59   2.07  44.56  0.97  0.13  0.33  0.06  0.02  124.42
# 3    A2-2   7.34   0.84   0.82  46.18  3.74  0.67  0.10  0.04  0.02  209.18
# 4    A2-5   5.67   1.17   1.40  49.81  1.19  0.24  0.19  0.05  0.02  274.18
#
#      SM    AM           depth
# 0  5.66  1.13    Avg of 2 Mts
# 1  1.82  0.85    Avg of 3 Mts
# 2  3.18  0.77  Avg of 1.5 Mts
# 3  4.42  1.02    Avg of 2 Mts
# 4  2.21  0.84    Avg of 3 Mts

# %%
df.columns
# Out:
# Index(['rows', 'SiO2', 'Al2O3', 'Fe2O3', 'CaO', 'MgO', 'SO3', 'K2O', 'Na2O',
#        'CL', 'LSF', 'SM', 'AM', 'depth'],
#       dtype='object')

# %%
oxides
# Out:
# ['SiO2', 'Al2O3', 'Fe2O3', 'CaO', 'MgO', 'SO3 ', 'Na2O', 'K2O', 'Na2O.1', 'Cl']

# %%
import seaborn as sns
oxides = ['SiO2', 'Al2O3', 'Fe2O3', 'CaO', 'MgO', 'SO3', 'Na2O', 'K2O', 'Na2O', 'CL']
palette = sns.color_palette("tab10", len(oxides))

cols= 3
rows = math.ceil(len(oxides) / cols)


plt.figure(figsize=(15, 5 * rows))

for i, (oxide, color) in enumerate(zip(oxides, palette), 1):
    plt.subplot(rows, cols, i)
    
    data = df[oxide].dropna()
    
    sns.violinplot(y=data, color='lightgray', inner=None)
    sns.swarmplot(y=data, color=color, size=2)
    
    plt.title(oxide)

plt.tight_layout()
plt.show()

# %%
import math
import matplotlib.pyplot as plt
import seaborn as sns

def plot_oxide_distribution(df, oxides, cols=3, plot_type="violin+swarm"):
    """
    plot_type options:
    - 'violin'
    - 'box'
    - 'swarm'
    - 'violin+swarm'
    - 'box+swarm'
    """

    oxides = list(dict.fromkeys(oxides))  # remove duplicates
    palette = sns.color_palette("tab10", len(oxides))

    rows = math.ceil(len(oxides) / cols)
    plt.figure(figsize=(15, 5 * rows))

    for i, (oxide, color) in enumerate(zip(oxides, palette), 1):
        plt.subplot(rows, cols, i)

        if oxide not in df.columns:
            print(f"Warning: {oxide} not found")
            continue

        data = df[oxide].dropna()

        # ---- plotting logic ----
        if plot_type == "violin":
            sns.violinplot(y=data, color="lightgray")

        elif plot_type == "box":
            sns.boxplot(y=data, color="lightgray")

        elif plot_type == "swarm":
            sns.swarmplot(y=data, color=color, size=3)

        elif plot_type == "violin+swarm":
            sns.violinplot(y=data, color="lightgray", inner=None,hue='rows')
            sns.swarmplot(y=data, color=color, size=2)

        elif plot_type == "box+swarm":
            sns.boxplot(y=data, color="lightgray")
            sns.swarmplot(y=data, color=color, size=2)

        else:
            raise ValueError("Invalid plot_type")

        plt.title(oxide)

    plt.tight_layout()
    plt.show()

# %%
plot_oxide_distribution(df, oxides, cols=3, plot_type="box+swarm")

# %%
df[oxides]
# Out:
#     SiO2  Al2O3  Fe2O3    CaO   MgO   SO3  Na2O   K2O  Na2O    CL
# 0  13.76   1.29   1.14  38.84  7.35  0.61  0.05  0.11  0.05  0.02
# 1   4.16   1.05   1.24  50.68  1.12  0.22  0.04  0.16  0.04  0.01
# 2  11.64   1.59   2.07  44.56  0.97  0.13  0.06  0.33  0.06  0.02
# 3   7.34   0.84   0.82  46.18  3.74  0.67  0.04  0.10  0.04  0.02
# 4   5.67   1.17   1.40  49.81  1.19  0.24  0.05  0.19  0.05  0.02
# 5  11.98   1.71   2.22  44.13  1.09  0.28  0.06  0.39  0.06  0.05
# 6  18.50   0.97   1.27  42.13  1.17  0.61  0.02  0.12  0.02  0.00
# 7   9.40   1.00   1.24  48.14  0.86  0.21  0.03  0.14  0.03  0.01
# 8   8.42   1.46   1.53  47.97  0.85  0.14  0.05  0.29  0.05  0.03

# %%
means = df[oxides].mean().reset_index()
means.columns = ['Oxide', 'Value']

# %%
df[oxides]
# Out:
#     SiO2  Al2O3  Fe2O3    CaO   MgO   SO3  Na2O   K2O  Na2O    CL
# 0  13.76   1.29   1.14  38.84  7.35  0.61  0.05  0.11  0.05  0.02
# 1   4.16   1.05   1.24  50.68  1.12  0.22  0.04  0.16  0.04  0.01
# 2  11.64   1.59   2.07  44.56  0.97  0.13  0.06  0.33  0.06  0.02
# 3   7.34   0.84   0.82  46.18  3.74  0.67  0.04  0.10  0.04  0.02
# 4   5.67   1.17   1.40  49.81  1.19  0.24  0.05  0.19  0.05  0.02
# 5  11.98   1.71   2.22  44.13  1.09  0.28  0.06  0.39  0.06  0.05
# 6  18.50   0.97   1.27  42.13  1.17  0.61  0.02  0.12  0.02  0.00
# 7   9.40   1.00   1.24  48.14  0.86  0.21  0.03  0.14  0.03  0.01
# 8   8.42   1.46   1.53  47.97  0.85  0.14  0.05  0.29  0.05  0.03

# %%
import numpy as np
sns.barplot(data=df[oxides],estimator=np.mean)
# Out:
# <Axes: >

# %%
import numpy as np
sns.barplot(data=df[oxides],errorbar="sd")
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#             SiO2     Al2O3     Fe2O3        CaO       MgO       SO3       K2O  \
# count   9.000000  9.000000  9.000000   9.000000  9.000000  9.000000  9.000000
# mean   10.096667  1.231111  1.436667  45.826667  2.037778  0.345556  0.203333
# std     4.411632  0.301058  0.446962   3.815331  2.187114  0.218924  0.106536
# min     4.160000  0.840000  0.820000  38.840000  0.850000  0.130000  0.100000
# 25%     7.340000  1.000000  1.240000  44.130000  0.970000  0.210000  0.120000
# 50%     9.400000  1.170000  1.270000  46.180000  1.120000  0.240000  0.160000
# 75%    11.980000  1.460000  1.530000  48.140000  1.190000  0.610000  0.290000
# max    18.500000  1.710000  2.220000  50.680000  7.350000  0.670000  0.390000
#
#            Na2O        CL         LSF        SM        AM
# count  9.000000  9.000000    9.000000  9.000000  9.000000
# mean   0.044444  0.020000  180.358889  3.957778  0.877778
# std    0.013333  0.014142   93.721948  2.000855  0.128916
# ...

# %%
df_melt = df[oxides].melt(var_name="Oxide", value_name="Value")

sns.barplot(x="Oxide", y="Value", data=df_melt,estimator='median')
# Out:
# <Axes: xlabel='Oxide', ylabel='Value'>

# %%
sns.histplot(df['SO3'])
# Out:
# <Axes: xlabel='SO3', ylabel='Count'>

# %%
df.describe()
# Out:
#             SiO2     Al2O3     Fe2O3        CaO       MgO       SO3       K2O  \
# count   9.000000  9.000000  9.000000   9.000000  9.000000  9.000000  9.000000
# mean   10.096667  1.231111  1.436667  45.826667  2.037778  0.345556  0.203333
# std     4.411632  0.301058  0.446962   3.815331  2.187114  0.218924  0.106536
# min     4.160000  0.840000  0.820000  38.840000  0.850000  0.130000  0.100000
# 25%     7.340000  1.000000  1.240000  44.130000  0.970000  0.210000  0.120000
# 50%     9.400000  1.170000  1.270000  46.180000  1.120000  0.240000  0.160000
# 75%    11.980000  1.460000  1.530000  48.140000  1.190000  0.610000  0.290000
# max    18.500000  1.710000  2.220000  50.680000  7.350000  0.670000  0.390000
#
#            Na2O        CL         LSF        SM        AM
# count  9.000000  9.000000    9.000000  9.000000  9.000000
# mean   0.044444  0.020000  180.358889  3.957778  0.877778
# std    0.013333  0.014142   93.721948  2.000855  0.128916
# ...
