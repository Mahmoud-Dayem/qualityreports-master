# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
x = [9,12,10,55,62,50]
df = pd.Series(x)

# %%
sns.kdeplot(df)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.kdeplot(df,cumulative=True)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.violinplot(df)
# Out:
# <Axes: >

# %%
df
# Out:
# 0     9
# 1    12
# 2    10
# 3    55
# 4    62
# 5    50
# dtype: int64

# %%
sns.kdeplot(df['so2'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 sns.kdeplot(df['so2'])
#
# File c:\Users\mahmo\miniconda3\envs\streamlit-env\Lib\site-packages\pandas\core\series.py:1133, in Series.__getitem__(self, key)
#    1130     return self._values[key]
#    1132 elif key_is_scalar:
# -> 1133     return self._get_value(key)
#    1135 # Convert generator to list before going through hashable part
#    1136 # (We will iterate through the generator there to check for slices)
#    1137 if is_iterator(key):
#
# File c:\Users\mahmo\miniconda3\envs\streamlit-env\Lib\site-packages\pandas\core\series.py:1249, in Series._get_value(self, label, takeable)
#    1246     return self._values[label]
#    1248 # Similar to Index.get_value, but we do not fall back to positional
# -> 1249 loc = self.index.get_loc(label)
#    1251 if is_integer(loc):
# ...
