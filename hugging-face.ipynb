# %%
from transformers import pipeline, set_seed

pipe = pipeline("text-generation", model="gpt2")
set_seed(42)

result = pipe("what is the sun", max_length=30, num_return_sequences=5)

for i, r in enumerate(result):
    print(f"{i+1}: {r['generated_text']}")
# Out:
# Loading weights: 100%|██████████| 148/148 [00:00<00:00, 7363.58it/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 1: what is the sun's name?"
#
# "The sun is the first light in the universe."
#
# "But how does one explain it?"
#
# "The whole universe is a gigantic galaxy, it's got many stars, the sun is the first light in the universe. So why the name?"
#
# "The most important thing is to be like the sun and not like the sun, because the sun is the first light in the universe. So why the name?"
#
# "The more we learn about the sun, the better we will be at life. So why the name? Because we can't explain it as it is, because the sun is the first light in the universe."
#
# When I asked how the sun is lighted, she said it is actually a rainbow of light that is the sun's color.
#
# "The sun is the first light in the universe. So why the name?"
#
# "Because it is the first light in the universe."
#
# The sun is the first light in the universe, so why the name? Because it is the first light in the universe, so why the name?"
#
# When I asked her why she chose it, she said that it is because a lot of people choose it because of its color
# 2: what is the sun's position, and how does it see us?
#
# And by nature we have no idea whether it is in the night, or on the morning, or in the middle of the day. (B.S. 1812)
#
# The sun is visible only during the night.
#
# It is a sign of the solar system that the sun is always moving in the same direction as you and me and the air is moving in the same direction. If you take a compass you will see that the sun is moving by a line perpendicular to the Earth.
#
# The same principle applies to your brain. The first thing you learn about the brain is that it processes information by means of a series of waves. (B.S. 1812)
#
# The brain does not process information by means of waves. It process information by means of waves.
#
# The brain is the source of information. The brain is the source of information.
#
# The brain is the source of information.
#
# The brain is the source of information.
#
# The brain is the source of information.
#
# The brain is the source of information.
#
# The brain is the source of information.
#
# The brain is the source of information.
#
# The brain is
# 3: what is the sun?
#
# It's been a long time since I've seen a sun. I've seen it on a lot of different planets. In the space between my solar system and the sun, it's been pretty much the same thing.
#
# How do you feel about the current state of space exploration, how does that affect you?
#
# Well, I think the first step is to sort of move on. I want to be a big fan of space exploration. I have a lot of interest in space travel, so I'm looking forward to it.
#
# What are the most exciting things about space travel today?
#
# The coolest thing is that everything is going to be open. I'm trying to see how I can make space travel better. I'm trying to see how I can make space travel better.
#
# What do you think of NASA's future space plan?
#
# I'm not ready to say now, but after they get these kids out of the solar system, they'll have to figure out what they can do.
#
# It's interesting to see what the next steps are in space exploration. I'm just looking forward to it.
# 4: what is the sun?
#
# You know, you go to his house. He has a big, big, big window, and you look at it and you know he's sitting there, and you know, you know, he's just sitting there. And then he says, "Hey, I got some sunscreen." And you know, you're like, "Well, I can smell it." I'm like, "What's up?" And he just goes, "Oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh, oh,
# 5: what is the sun? If you can't see the sun, you can't see the moon.
#
# The sun is invisible, but it is there.
#
# The sun is invisible to you in the universe.
#
# The sun is invisible to you in the universe.
#
# The sun is invisible to you in the universe.
#
# The sun is invisible to you in the universe.
#
# The sun is invisible to you in the universe.
#
# The sun is invisible to you in the universe.
#
# The sun is invisible to you in the universe.
#
# The sun is invisible to you in the universe.
#
# The sun is invisible to you in the universe.
#
# The sun is invisible to you in the universe.
#
# The sun is invisible to you in the universe.
#
# The sun is invisible to you in the universe.
#
# The sun is invisible to you in the universe.
#
# The sun is invisible to you in the universe.
#
# The sun is invisible to you in the universe.
#
# The sun is invisible to you in the universe.
#
# The sun is invisible to you in the universe.
#
# The sun is invisible to you in the universe.
#
# The sun is invisible to you in the universe.

# %%
from transformers import AutoTokenizer

# load tokenizer (for GPT-2)
tokenizer = AutoTokenizer.from_pretrained("gpt2")

text = "mazenmahmoud"

# tokenize
tokens = tokenizer.tokenize(text)

# convert to IDs
token_ids = tokenizer.convert_tokens_to_ids(tokens)

print("Tokens:", tokens)
print("Token IDs:", token_ids)
# Out:
# Tokens: ['m', 'az', 'en', 'm', 'ah', 'm', 'oud']
# Token IDs: [76, 1031, 268, 76, 993, 76, 2778]

# %%
print(tokenizer)
# Out:
# GPT2Tokenizer(name_or_path='gpt2', vocab_size=50257, model_max_length=1024, padding_side='right', truncation_side='right', special_tokens={'bos_token': '<|endoftext|>', 'eos_token': '<|endoftext|>', 'unk_token': '<|endoftext|>'}, added_tokens_decoder={
# 	50256: AddedToken("<|endoftext|>", rstrip=False, lstrip=False, single_word=False, normalized=True, special=True),
# })

# %%
from transformers import AutoModelForCausalLM

gpt2 = AutoModelForCausalLM.from_pretrained('gpt2')
# Out:
# Loading weights: 100%|██████████| 148/148 [00:00<00:00, 4271.95it/s]

# %%
sentence = ' i like basma to'
token_ids = tokenizer(sentence,return_tensors='pt').input_ids
gpt2(token_ids)
# Out:
# CausalLMOutputWithCrossAttentions(loss=None, logits=tensor([[[ -35.4452,  -35.2222,  -37.6430,  ...,  -43.3639,  -41.4534,
#            -35.6016],
#          [ -74.1607,  -75.7252,  -80.6902,  ...,  -84.3668,  -84.0866,
#            -77.4840],
#          [ -55.1286,  -55.1425,  -57.0718,  ...,  -65.8248,  -62.7220,
#            -57.3674],
#          [ -76.6354,  -77.5113,  -81.1216,  ...,  -87.7129,  -87.7340,
#            -79.2573],
#          [ -96.2166,  -97.3382, -100.8750,  ..., -104.1836, -104.3696,
#            -97.9457]]], grad_fn=<UnsafeViewBackward0>), past_key_values=DynamicCache(layers=[DynamicLayer, DynamicLayer, DynamicLayer, DynamicLayer, DynamicLayer, DynamicLayer, DynamicLayer, DynamicLayer, DynamicLayer, DynamicLayer, DynamicLayer, DynamicLayer]), hidden_states=None, attentions=None, cross_attentions=None)
